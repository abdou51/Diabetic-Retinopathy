# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-cls.pt')  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data='dataset', epochs=50, imgsz=256,batch=6)
# Out:
# ...
# 100%|██████████| 5.28M/5.28M [00:05<00:00, 1.06MB/s]
# New https://pypi.org/project/ultralytics/8.2.16 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.198  Python-3.11.2 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...
